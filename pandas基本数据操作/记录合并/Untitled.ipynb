# %%
import pandas
from pandas import read_csv
# 记录合并  concat([dataFrame1, dataFrame2, ...])   返回值dataFrame
df1 = read_csv('./data1.csv', sep="|")
df1
# Out:
#         id  comments                                              title
# 0  1235465      3256  台电（Teclast）X98 Air Ⅱ 9.7英寸平板电脑 (Intel 3736F 2....
# 1  1312660       342  台电（Teclast）X10HD 3G 双系统 10.1英寸平板电脑(Win8+安卓 256...
# 2  1192758      1725  台电（Teclast）P98 Air八核 9.7英寸平板电脑 (A80T八核 Air视网膜屏...
# 3  1312671       279  台电（Teclast）X89 双系统版 7.9英寸平板电脑 (IntelZ3735 分辨率2...
# 4  1094550      2563  台电（Teclast） P19HD 10.1英寸平板电脑(Intel Z2580 2.0G主...
# 5  1327452       207  台电（Teclast）P80 3G八核 8英寸平板电脑(3G通话 MT8392八核  128...

# %%
df2 = read_csv('./data2.csv', sep="|")
df2
# Out:
#         id  comments                                              title
# 0  1134006     13231  小米（MI）7.9英寸平板 WIFI 16GB（NVIDIA Tegra K1 2.2GHz...
# 1  1192330      6879  小米（MI）7.9英寸平板 WIFI 64GB（NVIDIA Tegra K1 2.2GHz...
# 2  1225995      2218  小米（MI）7.9英寸平板 WIFI 16GB（NVIDIA Tegra K1 2.2GHz...
# 3  1225988      1336  小米（MI）7.9英寸平板 WIFI 16GB（NVIDIA Tegra K1 2.2GHz...
# 4  1284247       578  小米（MI）7.9英寸平板 WIFI 64GB（NVIDIA Tegra K1 2.2GHz...

# %%
df3 = read_csv('./data3.csv', sep="|")
df3
# Out:
#         id  comments                                              title
# 0   996961     62014     Apple iPad Air MD788CH 9.7英寸平板电脑 （16G WiFi版）银色
# 1   996967     59503  Apple iPad mini ME279CH/A 配备 Retina 显示屏 7.9英寸平...
# 2   761145    123415  Apple iPad mini MD531CH/A 7.9英寸平板电脑 （16G WIFI版）白色
# 3  1246836      8791  Apple iPad Air 2 MH0W2CH/A 9.7英寸平板电脑 （16G WiFi...
# 4   996964      9332  Apple iPad mini ME280CH/A 配备 Retina 显示屏 7.9英寸平...
# 5  1250967      4932  Apple iPad Air 2 MH182CH/A 9.7英寸平板电脑 （64G WiFi...

# %%
df = pandas.concat([df1, df2, df3])
df
# Out:
#         id  comments                                              title
# 0  1235465      3256  台电（Teclast）X98 Air Ⅱ 9.7英寸平板电脑 (Intel 3736F 2....
# 1  1312660       342  台电（Teclast）X10HD 3G 双系统 10.1英寸平板电脑(Win8+安卓 256...
# 2  1192758      1725  台电（Teclast）P98 Air八核 9.7英寸平板电脑 (A80T八核 Air视网膜屏...
# 3  1312671       279  台电（Teclast）X89 双系统版 7.9英寸平板电脑 (IntelZ3735 分辨率2...
# 4  1094550      2563  台电（Teclast） P19HD 10.1英寸平板电脑(Intel Z2580 2.0G主...
# 5  1327452       207  台电（Teclast）P80 3G八核 8英寸平板电脑(3G通话 MT8392八核  128...
# 0  1134006     13231  小米（MI）7.9英寸平板 WIFI 16GB（NVIDIA Tegra K1 2.2GHz...
# 1  1192330      6879  小米（MI）7.9英寸平板 WIFI 64GB（NVIDIA Tegra K1 2.2GHz...
# 2  1225995      2218  小米（MI）7.9英寸平板 WIFI 16GB（NVIDIA Tegra K1 2.2GHz...
# 3  1225988      1336  小米（MI）7.9英寸平板 WIFI 16GB（NVIDIA Tegra K1 2.2GHz...
# 4  1284247       578  小米（MI）7.9英寸平板 WIFI 64GB（NVIDIA Tegra K1 2.2GHz...
# 0   996961     62014     Apple iPad Air MD788CH 9.7英寸平板电脑 （16G WiFi版）银色
# ...
